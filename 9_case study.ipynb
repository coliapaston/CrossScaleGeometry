# %% [markdown]
# # Case Study
#
# Input `model_name`, `tokenizer`, `query_token`, and `seed_list`, then inspect the token's cluster contents across full and random partitions.

# %%
# import matplotlib.pyplot as plt
import numpy as np
# from sklearn.utils.extmath import randomized_svd
# from scipy.signal import savgol_filter, find_peaks
from transformers import AutoTokenizer
import torch

# %%
import sys
sys.path.append("./cluster_anlys")

from case_study import collect_token_case_study, print_case_study_report

# %%
model_name = "mistralai/Mistral-7B-v0.1"
# ===== Step 1: Load tokenizer =====
tokenizer_path = f"{model_name}/tokenizer" 
tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
print(f"[✓] Tokenizer loaded from: {tokenizer_path}")

# ===== Step 2: Load lm_head.weight =====
space_name = "output_proj"
lm_head_path = f"{model_name}/tensors/{space_name}.pt" 
embedding_matrix = torch.load(lm_head_path, map_location="cpu")
print(f"[✓] lm_head.weight loaded: shape = {embedding_matrix.shape}")
embedding_matrix = embedding_matrix.to(torch.float32)
# embedding_matrix = embedding_matrix.cpu().to(torch.float32).numpy()
print(f"[✓] lm_head.weight loaded: shape = {embedding_matrix.shape}")
# Out:
# [✓] Tokenizer loaded from: mistralai/Mistral-7B-v0.1/tokenizer
# [✓] lm_head.weight loaded: shape = torch.Size([32000, 4096])
# [✓] lm_head.weight loaded: shape = torch.Size([32000, 4096])

# %%
# model_name = "mistralai/Mistral-7B-v0.1"
# tokenizer = ...
query_token = "dopo"
seed_list = [0, 42, 1000, 9999, 1813382118, 827307999, 1627694678, 1911784257]

# %%
case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: dopo
# query_token_id: 14752
# num_matches: 81
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=71, cluster_size=117
# partition_type=full, seed=None, pca_dim=997, cluster_id=442, cluster_size=27
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3459, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3938, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4088, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4096, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=72, cluster_size=38
# ...

# %%
query_token = "拖"
seed_list = [0, 42, 1000, 9999, 1813382118, 827307999, 1627694678, 1911784257]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 拖
# query_token_id: 31454
# num_matches: 81
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=335, cluster_size=8
# partition_type=full, seed=None, pca_dim=2084, cluster_id=451, cluster_size=8
# partition_type=full, seed=None, pca_dim=3031, cluster_id=392, cluster_size=8
# partition_type=full, seed=None, pca_dim=3459, cluster_id=400, cluster_size=8
# partition_type=full, seed=None, pca_dim=3938, cluster_id=410, cluster_size=8
# partition_type=full, seed=None, pca_dim=4088, cluster_id=236, cluster_size=12
# partition_type=full, seed=None, pca_dim=4096, cluster_id=241, cluster_size=12
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=-1, cluster_size=0
# ...

# %%
query_token = "octubre"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: octubre
# query_token_id: 25154
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=69, cluster_size=7
# partition_type=full, seed=None, pca_dim=997, cluster_id=481, cluster_size=9
# partition_type=full, seed=None, pca_dim=2084, cluster_id=824, cluster_size=8
# partition_type=full, seed=None, pca_dim=3031, cluster_id=891, cluster_size=8
# partition_type=full, seed=None, pca_dim=3459, cluster_id=913, cluster_size=8
# partition_type=full, seed=None, pca_dim=3938, cluster_id=928, cluster_size=8
# partition_type=full, seed=None, pca_dim=4088, cluster_id=941, cluster_size=8
# partition_type=full, seed=None, pca_dim=4096, cluster_id=948, cluster_size=8
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=62, cluster_size=7
# ...

# %%
query_token = "Massachusetts"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: Massachusetts
# query_token_id: 16255
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=70, cluster_size=6
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=512, cluster_size=7
# partition_type=full, seed=None, pca_dim=3459, cluster_id=569, cluster_size=12
# partition_type=full, seed=None, pca_dim=3938, cluster_id=573, cluster_size=12
# partition_type=full, seed=None, pca_dim=4088, cluster_id=592, cluster_size=12
# partition_type=full, seed=None, pca_dim=4096, cluster_id=597, cluster_size=12
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=61, cluster_size=7
# ...

# %%
# rep
query_token = "▁Emb"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: ▁Emb
# query_token_id: 18065
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=106, cluster_size=13
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=162, cluster_size=11
# partition_type=full, seed=None, pca_dim=2084, cluster_id=236, cluster_size=10
# partition_type=full, seed=None, pca_dim=3031, cluster_id=232, cluster_size=10
# partition_type=full, seed=None, pca_dim=3459, cluster_id=215, cluster_size=10
# partition_type=full, seed=None, pca_dim=3938, cluster_id=217, cluster_size=10
# partition_type=full, seed=None, pca_dim=4088, cluster_id=223, cluster_size=10
# partition_type=full, seed=None, pca_dim=4096, cluster_id=228, cluster_size=10
# partition_type=random, seed=0, pca_dim=5, cluster_id=117, cluster_size=11
# partition_type=random, seed=0, pca_dim=142, cluster_id=-1, cluster_size=0
# ...

# %%
query_token = "高"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 高
# query_token_id: 29366
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3459, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3938, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4088, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4096, cluster_id=881, cluster_size=11
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=-1, cluster_size=0
# ...

# %%
query_token = "特"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 特
# query_token_id: 29631
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=626, cluster_size=8
# partition_type=full, seed=None, pca_dim=3459, cluster_id=637, cluster_size=8
# partition_type=full, seed=None, pca_dim=3938, cluster_id=646, cluster_size=8
# partition_type=full, seed=None, pca_dim=4088, cluster_id=643, cluster_size=8
# partition_type=full, seed=None, pca_dim=4096, cluster_id=650, cluster_size=8
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=-1, cluster_size=0
# ...

# %%
query_token = "项"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 项
# query_token_id: 29541
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=656, cluster_size=9
# partition_type=full, seed=None, pca_dim=3031, cluster_id=867, cluster_size=9
# partition_type=full, seed=None, pca_dim=3459, cluster_id=895, cluster_size=9
# partition_type=full, seed=None, pca_dim=3938, cluster_id=895, cluster_size=9
# partition_type=full, seed=None, pca_dim=4088, cluster_id=908, cluster_size=9
# partition_type=full, seed=None, pca_dim=4096, cluster_id=917, cluster_size=9
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=-1, cluster_size=0
# ...

# %%
# query_token = "favour"
query_token = "脚"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 脚
# query_token_id: 30646
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=91, cluster_size=9
# partition_type=full, seed=None, pca_dim=2084, cluster_id=80, cluster_size=9
# partition_type=full, seed=None, pca_dim=3031, cluster_id=103, cluster_size=9
# partition_type=full, seed=None, pca_dim=3459, cluster_id=84, cluster_size=9
# partition_type=full, seed=None, pca_dim=3938, cluster_id=77, cluster_size=9
# partition_type=full, seed=None, pca_dim=4088, cluster_id=68, cluster_size=9
# partition_type=full, seed=None, pca_dim=4096, cluster_id=68, cluster_size=9
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=-1, cluster_size=0
# ...

# %%
# query_token = "favour"
query_token = "三"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 三
# query_token_id: 29492
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3459, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3938, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4088, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4096, cluster_id=919, cluster_size=45
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=-1, cluster_size=0
# ...

# %%
# query_token = "favour"
query_token = "顶"
seed_list = [0]

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 顶
# query_token_id: 30118
# num_matches: 18
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3459, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3938, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4088, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4096, cluster_id=176, cluster_size=8
# partition_type=random, seed=0, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=random, seed=0, pca_dim=142, cluster_id=-1, cluster_size=0
# ...

# %%
# query_token = "favour"
query_token = '删'
seed_list = []

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 删
# query_token_id: 29327
# num_matches: 9
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=198, cluster_size=14
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=570, cluster_size=12
# partition_type=full, seed=None, pca_dim=2084, cluster_id=374, cluster_size=13
# partition_type=full, seed=None, pca_dim=3031, cluster_id=367, cluster_size=13
# partition_type=full, seed=None, pca_dim=3459, cluster_id=363, cluster_size=13
# partition_type=full, seed=None, pca_dim=3938, cluster_id=384, cluster_size=13
# partition_type=full, seed=None, pca_dim=4088, cluster_id=406, cluster_size=13
# partition_type=full, seed=None, pca_dim=4096, cluster_id=410, cluster_size=13
#
# ...
# partition_type=full | seed=None | pca_dim=5 | cluster_id=198 | cluster_size=14
# comp/mistralai/Mistral-7B-v0.1/output_proj/clusters_l2=True/run_00001_clusters.csv
# ...

# %%
# query_token = "favour"
query_token = "ших"
seed_list = []

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: ших
# query_token_id: 15994
# num_matches: 9
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=194, cluster_size=7
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=135, cluster_size=34
# partition_type=full, seed=None, pca_dim=3031, cluster_id=132, cluster_size=45
# partition_type=full, seed=None, pca_dim=3459, cluster_id=123, cluster_size=42
# partition_type=full, seed=None, pca_dim=3938, cluster_id=111, cluster_size=49
# partition_type=full, seed=None, pca_dim=4088, cluster_id=110, cluster_size=49
# partition_type=full, seed=None, pca_dim=4096, cluster_id=110, cluster_size=48
#
# ...
# partition_type=full | seed=None | pca_dim=5 | cluster_id=194 | cluster_size=7
# comp/mistralai/Mistral-7B-v0.1/output_proj/clusters_l2=True/run_00001_clusters.csv
# ...

# %%
# query_token = "favour"
query_token = "父"
seed_list = []

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 父
# query_token_id: 30276
# num_matches: 9
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=670, cluster_size=17
# partition_type=full, seed=None, pca_dim=3031, cluster_id=688, cluster_size=21
# partition_type=full, seed=None, pca_dim=3459, cluster_id=664, cluster_size=23
# partition_type=full, seed=None, pca_dim=3938, cluster_id=696, cluster_size=23
# partition_type=full, seed=None, pca_dim=4088, cluster_id=709, cluster_size=23
# partition_type=full, seed=None, pca_dim=4096, cluster_id=717, cluster_size=23
#
# ...
# partition_type=full | seed=None | pca_dim=5 | cluster_id=-1 | cluster_size=0
# comp/mistralai/Mistral-7B-v0.1/output_proj/clusters_l2=True/run_00001_clusters.csv
# ...

# %%
# query_token = "favour"
query_token = "international"
seed_list = []

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: international
# query_token_id: 5611
# num_matches: 9
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=159, cluster_size=329
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=763, cluster_size=9
# partition_type=full, seed=None, pca_dim=3459, cluster_id=778, cluster_size=9
# partition_type=full, seed=None, pca_dim=3938, cluster_id=803, cluster_size=9
# partition_type=full, seed=None, pca_dim=4088, cluster_id=823, cluster_size=9
# partition_type=full, seed=None, pca_dim=4096, cluster_id=833, cluster_size=9
#
# ...
# partition_type=full | seed=None | pca_dim=5 | cluster_id=159 | cluster_size=329
# ...

# %%
# query_token = "favour"
query_token = "internet"
seed_list = []

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: internet
# query_token_id: 7865
# num_matches: 9
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=159, cluster_size=329
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3459, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3938, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4088, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4096, cluster_id=-1, cluster_size=0
#
# ...
# partition_type=full | seed=None | pca_dim=5 | cluster_id=159 | cluster_size=329
# comp/mistralai/Mistral-7B-v0.1/output_proj/clusters_l2=True/run_00001_clusters.csv
# ...

# %%
# query_token = "favour"
# 791, 7182
query_token = 'connect'
seed_list = []

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: connect
# query_token_id: 7182
# num_matches: 9
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=997, cluster_id=482, cluster_size=30
# partition_type=full, seed=None, pca_dim=2084, cluster_id=583, cluster_size=31
# partition_type=full, seed=None, pca_dim=3031, cluster_id=722, cluster_size=29
# partition_type=full, seed=None, pca_dim=3459, cluster_id=723, cluster_size=29
# partition_type=full, seed=None, pca_dim=3938, cluster_id=732, cluster_size=29
# partition_type=full, seed=None, pca_dim=4088, cluster_id=753, cluster_size=29
# partition_type=full, seed=None, pca_dim=4096, cluster_id=761, cluster_size=29
#
# ...
# partition_type=full | seed=None | pca_dim=5 | cluster_id=-1 | cluster_size=0
# comp/mistralai/Mistral-7B-v0.1/output_proj/clusters_l2=True/run_00001_clusters.csv
# ...

# %%
# query_token = "favour"
query_token = 630
seed_list = []

case_result = collect_token_case_study(
    model_name=model_name,
    tokenizer=tokenizer,
    query_token=query_token,
    seed_list=seed_list,
)

print_case_study_report(case_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# query_token: 630
# query_token_id: 630
# num_matches: 9
#
# === Summary ===
# partition_type=full, seed=None, pca_dim=5, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=142, cluster_id=77, cluster_size=1091
# partition_type=full, seed=None, pca_dim=997, cluster_id=646, cluster_size=393
# partition_type=full, seed=None, pca_dim=2084, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3031, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3459, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=3938, cluster_id=-1, cluster_size=0
# partition_type=full, seed=None, pca_dim=4088, cluster_id=814, cluster_size=5
# partition_type=full, seed=None, pca_dim=4096, cluster_id=815, cluster_size=6
#
# ...
# partition_type=full | seed=None | pca_dim=5 | cluster_id=-1 | cluster_size=0
# comp/mistralai/Mistral-7B-v0.1/output_proj/clusters_l2=True/run_00001_clusters.csv
# ...

# %%
case_result["matches"][0]["cluster_content"] if case_result["matches"] else []

# %%
from case_study import compare_dim_non_noise_overlap, print_dim_non_noise_overlap_report

# %%
dim0 = 5
dim1 = 4096
seed_list = [0]

# %%
overlap_result = compare_dim_non_noise_overlap(
    model_name=model_name,
    tokenizer=tokenizer,
    seed_list=seed_list,
    dim0=dim0,
    dim1=dim1,
)

print_dim_non_noise_overlap_report(overlap_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# dim0: 5
# dim1: 4096
#
# ...
# partition_type=full | seed=None | dim0_token_count=3725 | dim1_token_count=10605 | overlap_count=1227 | overlap_ratio=0.093643
# ...

# %%
from case_study import compare_dim_non_noise_disjoint_tokens, print_dim_non_noise_disjoint_report

# %%
dim0 = 4088
dim1 = 4096
seed_list = [0]

# %%
disjoint_result = compare_dim_non_noise_disjoint_tokens(
    model_name=model_name,
    tokenizer=tokenizer,
    seed_list=seed_list,
    dim0=dim0,
    dim1=dim1,
)

print_dim_non_noise_disjoint_report(disjoint_result)
# Out:
# model_name: mistralai/Mistral-7B-v0.1
# dim0: 4088
# dim1: 4096
#
# ...
# partition_type=full | seed=None | dim0_token_count=10714 | dim1_token_count=10605 | disjoint_count=387
# ...
