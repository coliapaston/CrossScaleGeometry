# %%
import matplotlib.pyplot as plt
import numpy as np
import torch
# from transformers import AutoTokenizer

# %%
import sys
sys.path.append("./cluster_anlys")

from pca_hdbscan import run_pca

# %% [markdown]
# # Mistral-7B

# %%
model_name = "mistralai/Mistral-7B-v0.1"
# ===== Step 1: Load tokenizer =====
# tokenizer_path = f"{model_name}/tokenizer" 
# tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
# print(f"[✓] Tokenizer loaded from: {tokenizer_path}")

# ===== Step 2: Load lm_head.weight =====
space_name = "output_proj"
lm_head_path = f"{model_name}/tensors/{space_name}.pt" 
embedding_matrix = torch.load(lm_head_path, map_location="cpu")
print(f"[✓] lm_head.weight loaded: shape = {embedding_matrix.shape}")
embedding_matrix = embedding_matrix.to(torch.float32)
# embedding_matrix = embedding_matrix.cpu().to(torch.float32).numpy()
print(f"[✓] lm_head.weight loaded: shape = {embedding_matrix.shape}")
# Out:
# [✓] lm_head.weight loaded: shape = torch.Size([32000, 4096])
# [✓] lm_head.weight loaded: shape = torch.Size([32000, 4096])

# %%
out_root = "comp"           # 可改路径

X_pca_full, pca_meta = run_pca(
    X_np=embedding_matrix,
    model_name=model_name,
    out_root=out_root,
)

print("X_pca_full shape:", X_pca_full.shape)
print("Full dim:", pca_meta["full_dim"])
print("Cum explained variance:", pca_meta["explained_variance_ratio_sum"])
# Out:
# [✓] Full PCA finished | model=mistralai/Mistral-7B-v0.1 full_dim=4096 time=30.79s cum_var=1.000000
# [✓] Saved to: comp/mistralai/Mistral-7B-v0.1/full_pca
# X_pca_full shape: (32000, 4096)
# Full dim: 4096
# Cum explained variance: 1.0

# %% [markdown]
# # Mixtral-8x7B

# %%
from transformers import AutoTokenizer
import torch

model_name = "mistralai/Mixtral-8x7B-v0.1"
# ===== Step 1: Load tokenizer =====
# tokenizer_path = f"{model_name}/tokenizer" 
# tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
# print(f"[✓] Tokenizer loaded from: {tokenizer_path}")

# ===== Step 2: Load lm_head.weight =====
space_name = "output_proj"
lm_head_path = f"{model_name}/tensors/{space_name}.pt" 
embedding_matrix = torch.load(lm_head_path, map_location="cpu")
print(f"[✓] lm_head.weight loaded: shape = {embedding_matrix.shape}")
embedding_matrix = embedding_matrix.to(torch.float32)
# embedding_matrix = embedding_matrix.cpu().to(torch.float32).numpy()
print(f"[✓] lm_head.weight loaded: shape = {embedding_matrix.shape}")
# Out:
# [✓] lm_head.weight loaded: shape = torch.Size([32000, 4096])
# [✓] lm_head.weight loaded: shape = torch.Size([32000, 4096])

# %%
out_root = "comp"           # 可改路径

X_pca_full, pca_meta = run_pca(
    X_np=embedding_matrix,
    model_name=model_name,
    out_root=out_root,
)

print("X_pca_full shape:", X_pca_full.shape)
print("Full dim:", pca_meta["full_dim"])
print("Cum explained variance:", pca_meta["explained_variance_ratio_sum"])
# Out:
# [✓] Full PCA finished | model=mistralai/Mixtral-8x7B-v0.1 full_dim=4096 time=30.50s cum_var=1.000000
# [✓] Saved to: comp/mistralai/Mixtral-8x7B-v0.1/full_pca
# X_pca_full shape: (32000, 4096)
# Full dim: 4096
# Cum explained variance: 1.0

# %% [markdown]
# # gpt-oss-20B

# %%
model_name = "gpt-oss"
space_name = "output_proj"
# # ===== Step 1: Load tokenizer =====
# tokenizer_path = f"{model_name}/tokenizer" 
# tokenizer = AutoTokenizer.from_pretrained(tokenizer_path)
# print(f"[✓] Tokenizer loaded from: {tokenizer_path}")

# ===== Step 2: Load lm_head.weight =====
space_name = "output_proj"
lm_head_path = f"{model_name}/tensors/{space_name}.pt" 
embedding_matrix = torch.load(lm_head_path, map_location="cpu")
print(f"[✓] lm_head.weight loaded: shape = {embedding_matrix.shape}")
embedding_matrix = embedding_matrix.to(torch.float32)
# embedding_matrix = embedding_matrix.cpu().to(torch.float32).numpy()
print(f"[✓] lm_head.weight loaded: shape = {embedding_matrix.shape}")
# Out:
# [✓] lm_head.weight loaded: shape = torch.Size([201088, 2880])
# [✓] lm_head.weight loaded: shape = torch.Size([201088, 2880])

# %%
out_root = "comp"           # 可改路径

X_pca_full, pca_meta = run_pca(
    X_np=embedding_matrix,
    model_name=model_name,
    out_root=out_root,
)

print("X_pca_full shape:", X_pca_full.shape)
print("Full dim:", pca_meta["full_dim"])
print("Cum explained variance:", pca_meta["explained_variance_ratio_sum"])
# Out:
# [✓] Full PCA finished | model=gpt-oss full_dim=2880 time=58.58s cum_var=1.000000
# [✓] Saved to: comp/gpt-oss/full_pca
# X_pca_full shape: (201088, 2880)
# Full dim: 2880
# Cum explained variance: 1.0
